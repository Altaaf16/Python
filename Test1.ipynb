# %%
X = ("""""""""Hello World
Hello World
Hello World
Hello World
I love python
I love python
I love python
I love python""""""""")
print (X)
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# I love python
# I love python
# I love python
# I love python

# %%
Month = int(input("Enter your Month:"))

if Month >= 3 and Month <= 5:
   print("Spring")
if Month >=6 and Month <=8:
   print("Summer")
if Month >=9 and Month <=11:
    print("Autumn")
if Month >=12 and Month <=2:
    print("Winter")
if Month <=0 or Month >12:
    print("Error")
# Out:
# Error

# %%
Ans= ">>>>3<=3<9"

print(Ans)
# Out:
# >>>>3<=3<9

# %%
mystring=  "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

Space = mystring.count(" ")

Dot = mystring.count(".")

comma = mystring.count(",")

ignore=(Space+Dot+comma)


Text= (len(mystring))

print(Text-ignore)
# Out:
# 476

# %%
for i in range(2500,3500,5):
 print (i)
# Out:
# 2500
# 2505
# 2510
# 2515
# 2520
# 2525
# 2530
# 2535
# 2540
# 2545
# 2550
# 2555
# 2560
# 2565
# 2570
# 2575
# 2580
# 2585
# 2590
# 2595
# 2600
# 2605
# 2610
# 2615
# 2620
# 2625
# 2630
# 2635
# 2640
# 2645
# 2650
# 2655
# 2660
# 2665
# 2670
# 2675
# 2680
# 2685
# 2690
# 2695
# 2700
# 2705
# 2710
# 2715
# 2720
# 2725
# 2730
# 2735
# 2740
# 2745
# 2750
# 2755
# 2760
# 2765
# 2770
# 2775
# 2780
# 2785
# 2790
# 2795
# 2800
# 2805
# 2810
# 2815
# 2820
# 2825
# 2830
# 2835
# 2840
# 2845
# 2850
# 2855
# 2860
# 2865
# 2870
# 2875
# 2880
# 2885
# 2890
# 2895
# 2900
# 2905
# 2910
# 2915
# 2920
# 2925
# 2930
# 2935
# 2940
# 2945
# 2950
# 2955
# 2960
# 2965
# 2970
# 2975
# 2980
# 2985
# 2990
# 2995
# 3000
# 3005
# 3010
# 3015
# 3020
# 3025
# 3030
# 3035
# 3040
# 3045
# 3050
# 3055
# 3060
# 3065
# 3070
# 3075
# 3080
# 3085
# 3090
# 3095
# 3100
# 3105
# 3110
# 3115
# 3120
# 3125
# 3130
# 3135
# 3140
# 3145
# 3150
# 3155
# 3160
# 3165
# 3170
# 3175
# 3180
# 3185
# 3190
# 3195
# 3200
# 3205
# ...

# %%
for i in range(2500,3500,7):
 print (i)
# Out:
# 2500
# 2507
# 2514
# 2521
# 2528
# 2535
# 2542
# 2549
# 2556
# 2563
# 2570
# 2577
# 2584
# 2591
# 2598
# 2605
# 2612
# 2619
# 2626
# 2633
# 2640
# 2647
# 2654
# 2661
# 2668
# 2675
# 2682
# 2689
# 2696
# 2703
# 2710
# 2717
# 2724
# 2731
# 2738
# 2745
# 2752
# 2759
# 2766
# 2773
# 2780
# 2787
# 2794
# 2801
# 2808
# 2815
# 2822
# 2829
# 2836
# 2843
# 2850
# 2857
# 2864
# 2871
# 2878
# 2885
# 2892
# 2899
# 2906
# 2913
# 2920
# 2927
# 2934
# 2941
# 2948
# 2955
# 2962
# 2969
# 2976
# 2983
# 2990
# 2997
# 3004
# 3011
# 3018
# 3025
# 3032
# 3039
# 3046
# 3053
# 3060
# 3067
# 3074
# 3081
# 3088
# 3095
# 3102
# 3109
# 3116
# 3123
# 3130
# 3137
# 3144
# 3151
# 3158
# 3165
# 3172
# 3179
# 3186
# 3193
# 3200
# 3207
# 3214
# 3221
# 3228
# 3235
# 3242
# 3249
# 3256
# 3263
# 3270
# 3277
# 3284
# 3291
# 3298
# 3305
# 3312
# 3319
# 3326
# 3333
# 3340
# 3347
# 3354
# 3361
# 3368
# 3375
# 3382
# 3389
# 3396
# 3403
# 3410
# 3417
# 3424
# 3431
# 3438
# 3445
# 3452
# 3459
# 3466
# 3473
# 3480
# 3487
# ...

# %%
names=["Jhon","Tom","Paul","Eric","Rita","Sean"]
Answer =input("enter your name")
for name in names:

 if Answer==name:
  print (names.index(name))
# Out:
# 2

# %%
Num1 = input("Enter your first number")
Num2 = input("Enter your first number")
Num3 = input("Enter your first number")
Num4 = input("Enter your first number")
Num5 = input("Enter your first number")

if (Num1 >= Num2) and (Num1 >= Num3) and (Num1 >=Num4) and(Num1 >= Num4):
   largest = Num1
elif (Num2 >= Num1) and (Num2 >= Num3) and (Num2 >= Num4) and (Num2 >= Num5):
   largest = Num2
elif (Num3 >= Num1) and (Num3 >= Num2) and (Num3 >= Num4) and (Num3 >= Num5):
   largest = Num3
elif (Num4 >= Num1) and (Num4 >= Num2) and (Num4 >= Num3) and (Num4 >= Num5):
   largest = Num4
else:
   largest = Num5

print("The largest number is", largest)
# Out:
# The largest number is 6

# %%
Guess1 = input("play? Yes or No")
Total=0
while Guess1 != "No":
 Number = input("Input a number from 0 to 9")
 Total +=1
 import random
 Random =(random.randint(0,9))

 if(Number==Random):
  print("Conglaturation")
 else:
    print("Fail")
 Guess1 = input("play? Yes or No")
print(Total)
# Out:
# Fail
# Fail
# Fail
# Fail
# Fail
# 5

# %%
items=[[str(input("Enter Fruit")),int(input("Enter number"))], [str(input("Enter Fruit")),int(input("Enter number"))],[str(input("Enter Fruit")),int(input("Enter number"))] ]

print(items)
# Out:
# [['Aple', 1], ['Orange', 2], ['Banne', 2]]

# %%
items=[[str(input("Enter Fruit")),int(input("Enter price")),int(input("Enter stock"))], [str(input("Enter Fruit")),int(input("Enter price")),int(input("Enter stock"))],[str(input("Enter Fruit")),int(input("Enter price")),int(input("Enter stock"))] ]

#items=[["edsgf",int(46),int(46)], ["Enter Fruit",int(45),int(45)],["Enter Fruit",int(5),int(10)] ]
print(items)

output1=(items[0][1]*items[0][2])
output2=(items[1][1]*items[1][2])
output3=(items[2][1]*items[2][2])

print(output1+output2+output3)
# Out:
# [['Test', 100, 100], ['test', 100, 100], ['test', 100, 100]]
# 30000
